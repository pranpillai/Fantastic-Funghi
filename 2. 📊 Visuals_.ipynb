# %% [markdown]
# # 2. 📊 Visuals:
# Exported from Filament on Thu, 17 Mar 2022 19:28:38 GMT
#
# ---

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

##
from sklearn import datasets
import sklearn.metrics as sm
from sklearn.cluster import KMeans
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("mushrooms.csv") # reading in the cleaned mushroom data

# %%
# label encoding each column in order to create a hisplot and heatmap

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df = df.apply(le.fit_transform)
df.head()

# %% [markdown]
# ## ✅Histplots:

# %%
# we can see below that hisplots aren't the most useful visualisation to interpret our data

df.hist(figsize = (20,20))

# %% [markdown]
# ## ✅ Heatmap:

# %%
# heatmap isn't a great visual, its a little unclear as there are too many features
# but we can see more lighter colours overall, signifying that the features aren't too strongly correlated in general

plt.figure(figsize=(12,10)) 
sns.heatmap(df.corr(), annot=True,cmap ='RdYlGn')
